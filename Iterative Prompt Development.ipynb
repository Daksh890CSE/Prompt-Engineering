# %% [markdown]
# **Loading the API Key and relevant python librariers**

# %%
import os
import getpass
from google import genai

if "GEMINI_API_KEY" not in os.environ:
    os.environ["GEMINI_API_KEY"] = getpass.getpass("Paste your Gemini API Key: ")

client = genai.Client()
# Out:
# Paste your Gemini API Key:  ········

# %% [markdown]
# **Defining helper function to make it easier to use prompts and look at generated outputs using gemini-2.5-flash-lite**

# %%
def get_completion(prompt, model="gemini-2.5-flash-lite"):
    # Request generation from Gemini
    response = client.models.generate_content(
        model=model,
        contents=prompt
    )
    return response.text

# %% [markdown]
# **Generate a marketing product description from a product fact sheet**

# %%
fact_sheet_chair = """
OVERVIEW
- Part of a beautiful family of mid-century inspired office furniture, 
including filing cabinets, desks, bookcases, meeting tables, and more.
- Several options of shell color and base finishes.
- Available with plastic back and front upholstery (SWC-100) 
or full upholstery (SWC-110) in 10 fabric and 6 leather options.
- Base finish options are: stainless steel, matte black, 
gloss white, or chrome.
- Chair is available with or without armrests.
- Suitable for home or business settings.
- Qualified for contract use.

CONSTRUCTION
- 5-wheel plastic coated aluminum base.
- Pneumatic chair adjust for easy raise/lower action.

DIMENSIONS
- WIDTH 53 CM | 20.87”
- DEPTH 51 CM | 20.08”
- HEIGHT 80 CM | 31.50”
- SEAT HEIGHT 44 CM | 17.32”
- SEAT DEPTH 41 CM | 16.14”

OPTIONS
- Soft or hard-floor caster options.
- Two choices of seat foam densities: 
 medium (1.8 lb/ft3) or high (2.8 lb/ft3)
- Armless or 8 position PU armrests 

MATERIALS
SHELL BASE GLIDER
- Cast Aluminum with modified nylon PA6/PA66 coating.
- Shell thickness: 10 mm.
SEAT
- HD36 foam

COUNTRY OF ORIGIN
- Italy
"""

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# ## Elevate Your Workspace with Mid-Century Charm and Modern Comfort
#
# Introducing a stylish and versatile office chair that seamlessly blends iconic mid-century design with exceptional comfort and durability. Part of a stunning collection of coordinated office furniture, this chair is the perfect addition to any home or business setting, designed to impress and built to last.
#
# **Personalize Your Style:**
#
# Choose from a spectrum of beautiful shell colors and sophisticated base finishes to perfectly complement your existing decor. Whether you prefer the sleek allure of stainless steel, the modern edge of matte black, the pristine finish of gloss white, or the classic shine of chrome, your ideal aesthetic awaits.
#
# **Upholstery to Suit Your Taste:**
#
# Opt for the refined look of plastic back and front upholstery (SWC-100), or indulge in the luxurious feel of full upholstery (SWC-110). With an impressive selection of 10 exquisite fabric and 6 premium leather options, you can create a look that's uniquely yours.
#
# **Designed for Your Comfort:**
#
# Experience effortless adjustability with the pneumatic chair adjustment, allowing for smooth and easy raise or lower action. Select from two foam densities – medium (1.8 lb/ft3) or high (2.8 lb/ft3) – to ensure your ideal level of support. Tailor your seating experience further with the option of armless design or 8-position PU armrests, providing customized comfort throughout your workday.
#
# **Built for Performance:**
#
# The robust 5-wheel plastic-coated aluminum base provides exceptional stability and smooth mobility. Choose between soft or hard-floor caster options for optimal performance on any surface. Crafted with a 10 mm thick cast aluminum shell and premium HD36 foam, this chair is engineered for lasting comfort and support.
#
# **Italian Craftsmanship:**
#
# Proudly made in Italy, this chair embodies the elegance and quality synonymous with Italian design. Qualified for contract use, it's a testament to its durability and suitability for high-traffic environments.
#
# **Dimensions:**
#
# *   **Width:** 53 CM | 20.87”
# *   **Depth:** 51 CM | 20.08”
# *   **Height:** 80 CM | 31.50”
# *   **Seat Height:** 44 CM | 17.32”
# *   **Seat Depth:** 41 CM | 16.14”
#
# **Complete your mid-century inspired office with coordinating filing cabinets, desks, bookcases, and meeting tables from our beautiful collection.**

# %% [markdown]
# ## Issue 1: The text is too long
# - Limit the number of words/sentences/characters.

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# Elevate your workspace with this mid-century inspired office chair. Customizable with fabric or leather upholstery, multiple base finishes, and armrest options, it blends style and function for any home or business. Crafted in Italy for lasting quality and contract use.

# %%
len(response.split())
# Out:
# 40

# %% [markdown]
# ## Issue 2. Text focuses on the wrong details
# - Ask it to focus on the aspects that are relevant to the intended audience.

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

The description is intended for furniture retailers, 
so should be technical in nature and focus on the 
materials the product is constructed from.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# Crafted in Italy, this chair features a cast aluminum shell with nylon PA6/PA66 coating. Options include HD36 foam seating, a 5-wheel plastic-coated aluminum base, and stainless steel, matte black, gloss white, or chrome finishes. Available with or without armrests.

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

The description is intended for furniture retailers, 
so should be technical in nature and focus on the 
materials the product is constructed from.

At the end of the description, include every 7-character 
Product ID in the technical specification.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# Constructed with a cast aluminum shell featuring a durable nylon coating, this chair boasts a robust 5-wheel plastic-coated aluminum base. Its seat utilizes HD36 foam for optimal comfort. Available in various upholstery and base finishes.
#
# SWC-100, SWC-110

# %% [markdown]
# ## Issue 3. Description needs a table of dimensions
# - Ask it to extract information and organize it in a table.

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

The description is intended for furniture retailers, 
so should be technical in nature and focus on the 
materials the product is constructed from.

At the end of the description, include every 7-character 
Product ID in the technical specification.

Use at most 50 words.

After the description, include a table that gives the 
product's dimensions. The table should have two columns.
In the first column include the name of the dimension. 
In the second column include the measurements in inches only.

Give the table the title 'Product Dimensions'.

Format everything as HTML that can be used in a website. 
Place the description in a <div> element.

Technical specifications: ```{fact_sheet_chair}```
"""

response = get_completion(prompt)
print(response)
# Out:
# ```html
# <div>
#   Constructed with a durable cast aluminum shell featuring a PA6/PA66 coating, this chair offers a 10mm shell thickness. Upholstered in HD36 foam, it rests on a robust 5-wheel plastic-coated aluminum base for stability.
#   <br>
#   SWC-100, SWC-110
# </div>
#
# <h2>Product Dimensions</h2>
# <table>
#   <tr>
#     <td>Width</td>
#     <td>20.87</td>
#   </tr>
#   <tr>
#     <td>Depth</td>
#     <td>20.08</td>
#   </tr>
#   <tr>
#     <td>Height</td>
#     <td>31.50</td>
#   </tr>
#   <tr>
#     <td>Seat Height</td>
#     <td>17.32</td>
#   </tr>
#   <tr>
#     <td>Seat Depth</td>
#     <td>16.14</td>
#   </tr>
# </table>
# ```

# %% [markdown]
# **Load Python libraries to view HTML**

# %%
from IPython.display import display,HTML

# %%
display(HTML(response))
# Out:
# ```html
# <div>
#   Constructed with a durable cast aluminum shell featuring a PA6/PA66 coating, this chair offers a 10mm shell thickness. Upholstered in HD36 foam, it rests on a robust 5-wheel plastic-coated aluminum base for stability.
#   <br>
#   SWC-100, SWC-110
# </div>
#
# <h2>Product Dimensions</h2>
# <table>
#   <tr>
#     <td>Width</td>
#     <td>20.87</td>
#   </tr>
#   <tr>
#     <td>Depth</td>
#     <td>20.08</td>
#   </tr>
#   <tr>
#     <td>Height</td>
#     <td>31.50</td>
#   </tr>
#   <tr>
#     <td>Seat Height</td>
#     <td>17.32</td>
#   </tr>
#   <tr>
#     <td>Seat Depth</td>
#     <td>16.14</td>
#   </tr>
# </table>
# ```
